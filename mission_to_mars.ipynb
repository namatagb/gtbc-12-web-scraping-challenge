# %%
# Dependencies
import requests
import pymongo
import time
import pandas as pd
from bs4 import BeautifulSoup as bs
from splinter import Browser
from flask import Flask, render_template, redirect
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {"executable_path": ChromeDriverManager().install()}
browser = Browser("chrome", **executable_path, headless=True)
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 102.0.5005
# Get LATEST chromedriver version for 102.0.5005 google-chrome
# Trying to download new driver from https://chromedriver.storage.googleapis.com/102.0.5005.61/chromedriver_win32.zip
# Driver has been saved in cache [C:\Users\Giselle\.wdm\drivers\chromedriver\win32\102.0.5005.61]

# %% [markdown]
# ## NASA Mars News

# %%
# URL of page to be scraped and retreve that page
url = 'https://redplanetscience.com/'
browser.visit(url)

html = browser.html

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(html, 'html.parser')

# %%
# Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta1/dist/css/bootstrap.min.css" integrity="sha384-giJF6kkoqNQ00vy+HMDP7azOuL0xtbfIcaT9wjKHr8RbDVddVHyTfAAsrekwKmP1" rel="stylesheet"/>
#   <link href="css/font.css" rel="stylesheet" type="text/css"/>
#   <link href="css/app.css" rel="stylesheet" type="text/css"/>
#   <link crossorigin="anonymous" href="https://pro.fontawesome.com/releases/v5.10.0/css/all.css" integrity="sha384-AYmEC3Yw5cVb3ZcuHtOA93w35dYTsvhLPVnYs9eStHfGJvOvKxVfELGroGkvsg+p" rel="stylesheet"/>
#   <title>
#    News - Mars Exploration Program
#   </title>
#  </head>
#  <body>
#   <div class="col-md-12">
#    <div class="row">
#     <nav class="navbar navbar-expand-lg navbar-light fixed-top">
#      <div class="container-fluid">
#       <a class="navbar-brand" href="#">
# ...

# %%
article = soup.find("div", class_='list_text')

# %%
news_title = article.find("div", class_="content_title").text
news_p = article.find("div", class_ ="article_teaser_body").text

print(news_title)
print(news_p)
# Out:
# NASA's InSight Flexes Its Arm While Its 'Mole' Hits Pause
# Now that the lander's robotic arm has helped the mole get underground, it will resume science activities that have been on hold.

# %%
#browser.quit()

# %% [markdown]
# ## JPL Mars Space Images - Featured Image

# %%
# URL of page to be scraped and retreve that page
url = 'https://spaceimages-mars.com/'
browser.visit(url)
image_html = browser.html

# %%
soup = bs(image_html, 'html.parser')

# %%
image = soup.find("div", class_='floating_text_area')
image
# Out:
# <div class="floating_text_area">
# <h2 class="brand_title">FEATURED IMAGE</h2>
# <h1 class="media_feature_title">Dusty Space Cloud</h1>
# <br/>
# <a class="showimg fancybox-thumbs" href="image/featured/mars3.jpg" target="_blank"> <button class="btn btn-outline-light"> FULL IMAGE</button></a>
# </div>

# %%
href = image.a["href"]

# %%
image_url = url + href
print(image_url)
# Out:
# https://spaceimages-mars.com/image/featured/mars3.jpg

# %% [markdown]
# ## Mars Facts

# %%
url = 'https://galaxyfacts-mars.com/'
browser.visit(url)
mars_table = pd.read_html(url)
mars_table = pd.DataFrame(mars_table[0])

# %%
mars_table.columns = mars_table.iloc[0]
mars_table = mars_table[1:]
mars_table
# Out:
# 0 Mars - Earth Comparison             Mars            Earth
# 1               Diameter:         6,779 km        12,742 km
# 2                   Mass:  6.39 × 10^23 kg  5.97 × 10^24 kg
# 3                  Moons:                2                1
# 4      Distance from Sun:   227,943,824 km   149,598,262 km
# 5         Length of Year:   687 Earth days      365.24 days
# 6            Temperature:     -87 to -5 °C      -88 to 58°C

# %%
mars_table.to_html('table.html')

# %% [markdown]
# ## Mars Hemispheres

# %%
url = 'https://marshemispheres.com/'
browser.visit(url)

# %%
html = browser.html
soup = bs(html, 'html.parser')

# %%
hemispheres = soup.find_all('a', class_='ItemLink product-item')
hemispheres
# Out:
# []

# %%
image_list = []

for x in range(4):
    
    #hemispheres = soup.find_all('div', class_='description')
    
    image_dict = {}
    
    image_title = browser.find_by_tag('h3')
    image_dict['title'] = image_title
    
    image_title[x].click()
    
    html1 = browser.html
    soup1 = bs(html, 'html.parser')
    
    download = soup1.find('div', class_='downloads')
    
    original = download.find('a')['href']
    image_dict['img_url'] = original
    
    image_list.append(image_dict)
    
hemispheres
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\splinter\element_list.py in __getitem__(self, index)
#      38         try:
# ---> 39             return self._container[index]
#      40         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# <ipython-input-160-2cc0d5cca4ca> in <module>
#      10     image_dict['title'] = image_title
#      11
# ---> 12     image_title[x].click()
#      13
#      14     html1 = browser.html
#
# ~\anaconda3\lib\site-packages\splinter\element_list.py in __getitem__(self, index)
#      39             return self._container[index]
#      40         except IndexError:
# ---> 41             raise ElementDoesNotExist(
# ...

# %%
    image_dict['title'] = image_title
    
    browser.links.find_by_partial_text(image_title).click()
    
    html = browser.html
    soup = bs(html, 'html.parser')
    
    download = new_soup.find('div', class_='downloads')
    original = download.find('a')['href']
    image_dict['img_url'] = original
    image_list.append(image_dict)
    
hemispheres
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\splinter\element_list.py in __getitem__(self, index)
#      38         try:
# ---> 39             return self._container[index]
#      40         except IndexError:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# ElementDoesNotExist                       Traceback (most recent call last)
# <ipython-input-142-a1ce1b034e08> in <module>
#       1 image_dict['title'] = image_title
#       2
# ----> 3 browser.links.find_by_partial_text(image_title).click()
#       4
#       5 html = browser.html
#
# ~\anaconda3\lib\site-packages\splinter\element_list.py in __getattr__(self, name)
#      75     def __getattr__(self, name):
#      76         try:
# ---> 77             return getattr(self.first, name)
#      78         except AttributeError:
# ...
